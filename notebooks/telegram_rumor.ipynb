# %% [markdown]
# # Persian COVID-19 Fake News Detection — Telegram
#
# Telegram experiments reuse the same labeled dataset and pipeline.
#
# CLI equivalent:
#
# ```bash
# python -m src.cli train --platform telegram
# ```

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().resolve()
if not (PROJECT_ROOT / 'src').exists():
    PROJECT_ROOT = PROJECT_ROOT.parent
sys.path.insert(0, str(PROJECT_ROOT))

from src.utils import load_config
from src.preprocessing import load_dataset

config = load_config(PROJECT_ROOT / 'config/default.yaml')
data = load_dataset(str(PROJECT_ROOT / config['paths']['raw_dataset']), config)
print(data[config['data']['label_column']].value_counts())
